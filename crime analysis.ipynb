# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
crime_df = pd.read_csv("~/Desktop/test/data sets/crime.csv")

# %%
crime_df
# Out:
#     Unnamed: 0                 State State Code  Robbery  Aggravated Assault  \
# 0            0               Alabama         AL    141.4               247.8
# 1            1                Alaska         AK     80.9               465.1
# 2            2               Arizona         AZ    144.4               327.4
# 3            3              Arkansas         AR     91.1               386.8
# 4            4            California         CA    176.1               317.3
# 5            5              Colorado         CO     84.6               264.7
# 6            6           Connecticut         CT    113.0               138.6
# 7            7              Delaware         DC    154.8               428.2
# 8            8  District of Columbia         DE    672.1               721.3
# 9            9               Florida         FL    169.4               496.6
# 10          10               Georgia         GA    154.8               264.3
# ...

# %%
State = crime_df
Robbery = crime_df.nlargest(5, "Robbery")["State Code"]
Robbery
# fig, ax = plt.subplots()
# ax.bar(State, Robbery)
# fig.tight_layout()
# ax[1].set_edgecolor('red')
# ax[1].set_linestyle('-.')
# ax[1].set_linewidth(2)
# ax[1].set_alpha(.8)
# Out:
# 8     DE
# 20    MD
# 28    NV
# 32    NY
# 13    IL
# Name: State Code, dtype: object
